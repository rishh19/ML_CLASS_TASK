# %% [markdown]
# <a href="https://colab.research.google.com/github/rishh19/ML_CLASS_CSE11/blob/main/ml_dataset_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Student.csv")
print(df)
# Out:
#     Stud_Id        Name  Age  RollNo Section
# 0         1      rishav   20      10       A
# 1         2  priysanshu   20      11       B
# 2         3      roshan   21      12       C
# 3         4    shibhang   20      13       D
# 4         5       ishan   20      14       E
# 5         6       sumit   19      15       F
# 6         7       parth   20      16       G
# 7         8      shreya   21      17       H
# 8         9        kuhu   22      18       I
# 9        10      samyak   21      19       J
# 10       11       sumit   19      15       K
# 11       12       parth   20      16       L
# 12       13      shivam   21      17       M
# 13       14    vanshika   22      18       N
# 14       15         sam   21      19       O
# 15       16      prachi   19      15       P
# 16       17         isa   20      16       Q
# 17       18      akshat   21      17       R
# 18       19       naman   22      18       S
# 19       20       rahul   21      19       T

# %%
print(df.head())
# Out:
#    Stud_Id        Name  Age  RollNo Section
# 0        1      rishav   20      10       A
# 1        2  priysanshu   20      11       B
# 2        3      roshan   21      12       C
# 3        4    shibhang   20      13       D
# 4        5       ishan   20      14       E

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Stud_Id  20 non-null     int64
#  1   Name     20 non-null     object
#  2   Age      20 non-null     int64
#  3   RollNo   20 non-null     int64
#  4   Section  20 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 932.0+ bytes
# None
#         Stud_Id        Age     RollNo
# count  20.00000  20.000000  20.000000
# mean   10.50000  20.500000  15.750000
# std     5.91608   0.945905   2.653201
# min     1.00000  19.000000  10.000000
# 25%     5.75000  20.000000  14.750000
# 50%    10.50000  20.500000  16.000000
# 75%    15.25000  21.000000  18.000000
# max    20.00000  22.000000  19.000000
